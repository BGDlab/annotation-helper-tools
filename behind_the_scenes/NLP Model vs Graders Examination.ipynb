# %%
import pandas as pd
import numpy as np
import random
import os
from IPython.display import clear_output
from google.cloud import bigquery # SQL table interface on Arcus
import json
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Initialize the client service
client = bigquery.Client()

grader_table_name = "lab.grader_table_with_metadata_project_independent"
project_table_name = "lab.proc_ord_projects"

# %%
def print_report_experimental(
    proc_id, client, to_highlight={}, source_table="arcus.procedure_order_narrative"
):
    # Get the grading info for the proc_ord_id
    q_get_grade_row = ( 
        'select * from '
        + 'lab.grader_table_with_metadata_project_independent '
        + 'where proc_ord_id = "'
        + proc_id
        + '" '
    )
    df_grade = client.query(q_get_grade_row).to_dataframe()

    for idx, row in df_grade.iterrows():
        grader = row['grader_name']
        grade = row['grade']
        grade_date = row['grade_date']
        print("Grader", grader, "gave grade", grade, "on", grade_date)

    # Get the specifics of the grade of 0
    zero_row = df_grade[df_grade['grade'] == 0]
    s_zero_row = zero_row['grader_name'].values+" gave grade 0 on " + zero_row['grade_date'].values
        
    print("Age at scan:", (df_grade['age_in_days'].values[0]/365.25))
    print()
    
    
    # Get the report for that proc_ord_id from the primary report table
    try:
        q_get_report_row = (
            "SELECT * FROM "
            + source_table
            + ' where proc_ord_id like "'
            + str(proc_id)
            + '"'
        )
        df_report = client.query(q_get_report_row).to_dataframe()
    except:
        print(
            "AN ERROR HAS OCCURRED: REPORT", proc_id, "CANNOT BE FOUND IN", source_table
        )

    # If the id was in the new table:
    if len(df_report) == 1:
        origin_table = source_table
        domain = source_table.split(".")[0]

        q_get_report_row = (
            "SELECT * FROM "
            + domain
            + '.procedure_order_narrative where proc_ord_id = "'
            + str(proc_id)
            + '"'
        )
        report_text = (
            client.query(q_get_report_row).to_dataframe()["narrative_text"].values[0]
        )

        q_get_report_row = (
            "SELECT * FROM "
            + domain
            + '.procedure_order_impression where proc_ord_id = "'
            + str(proc_id)
            + '"'
        )
        df_report = client.query(q_get_report_row).to_dataframe()

        if len(df_report) == 1:
            report_text += "\n\nIMPRESSION: " + df_report["impression_text"].values[0]

    elif len(df_report) == 0:
        print("proc_ord_id not in", source_table, ":", proc_id)

    report_text = " ".join(report_text.split())
    report_text = report_text.replace("CLINICAL INDICATION", "\n\nCLINICAL INDICATION")
    report_text = report_text.replace("TECHNIQUE", "\n\nTECHNIQUE")
    report_text = report_text.replace("HISTORY", "\n\nHISTORY")
    report_text = report_text.replace("IMPRESSION", "\n\nIMPRESSION")
    report_text = report_text.replace("FINDINGS", "\n\nFINDINGS")
    report_text = report_text.replace("COMPARISON", "\n\nCOMPARISON")

    # If the user passed a dictionary of lists to highlight
    if len(to_highlight.keys()) > 0:
        for key in to_highlight.keys():
            report_text = mark_text_color(report_text, to_highlight[key], key)

    # Print the report and ask for a grade
    print(report_text)
    print()
    # Print the proc_ord_id
    print("Report id:", str(proc_id))
    print()
    
    return s_zero_row

# %%
def mark_text_color(line, to_mark, color):
    # Sort the list of strings to highlight by length (longest to shortest)
    to_mark = sorted(to_mark, key=len)[::-1]

    if color == "green":
        start = "\x1b[5;30;42m"  # green background, bold black text
    elif color == "yellow":
        start = "\x1b[5;30;43m"  # yellow background, bold black text
    elif color == "red":
        start = "\x1b[5;30;41m"  # red background, bold black text
    elif color == "gray" or color == "grey":
        start = "\x1b[5;30;47m"  # gray background, bold black text

    end = "\x1b[0m"

    if line is np.nan:
        return "<No report available.>"

    if type(to_mark) == str:
        line = line.replace(to_mark, start + to_mark + end)

    elif type(to_mark) == list:
        for phrase in to_mark:
            line = line.replace(str(phrase), start + str(phrase).upper() + end)

    else:
        print("Error: the second argument must be either a string or a list of strings")

    return line

# %%
q_conflicting_reports = '''
select
  grades.proc_ord_id,
  grades.grade,
  nlp_predict.majority_vote,
  grades.pat_id,
  grades.proc_ord_year
from
  lab.grader_table_with_metadata_project_independent grades
  join lab.maryam_nlp_combined nlp_predict on grades.proc_ord_id = nlp_predict.proc_ord_id
where
  grade = 0
  and nlp_predict.bert = nlp_predict.biobert
  and nlp_predict.bert = nlp_predict.clinbert
  and nlp_predict.bert = nlp_predict.radbert
  and nlp_predict.bert = 2
  and grades.proc_ord_year = 2024
'''

# %%
df_conflicting_reports = client.query(q_conflicting_reports).to_dataframe()
l_conflicting_proc_ids = df_conflicting_reports['proc_ord_id'].values
l_header = ['proc_ord_id', 'orig_grader', 'reason_for_0', 'jenna_new_grade', 'correct_grader']
l_report_reasons = []

# Replace with the path to your .json file containing a dictionary of all the phrases you'd like to be highlighted
phrasesToHighlightFn = "../phrases_to_highlight.json"

# Load the dictionary of phrases to highlight in certain colors 
with open(phrasesToHighlightFn, 'r', encoding='utf-8') as f:
    to_highlight = json.load(f)

for conflicting_proc_id in l_conflicting_proc_ids:
    clear_output()
    orig_grader = print_report_experimental(conflicting_proc_id, client, to_highlight)
    reason_for_zero = str(input("Why does Jenna think was this report given a 0: "))
    new_grade_jenna = str(input("What grade would you give it now: "))
    ruling = str(input("Who was correct, models or human? "))
    l_report_reasons.append([conflicting_proc_id, orig_grader, reason_for_zero, new_grade_jenna, ruling])
# Out:
# Grader Jenna Schabdach gave grade 0 on 2024-08-27
# Grader NLP Models 2024-11-12 gave grade 2 on 2024-11-12
# Age at scan: 33.927446954141
#
# FETAL BRAIN AND SPINE MRI, WITHOUT CONTRAST;
#
# CLINICAL INDICATION: Cleft lip palate, sacral agenesis.
#
# TECHNIQUE: BRAIN: Sagittal T1, axial TSE T2, axial FLAIR, axial T1, and axial diffusion weighted imaging. SPINE: Sagittal T1, axial T1, sagittal TSE T2, axial TSE T2, and sagittal FLAIR. All sequences performed on 1.5 Tesla system. HASTE and TruFISP of the face were also performed.
#
# COMPARISON: None
#
# FINDINGS: BRAIN: MR imaging is somewhat LIMITED given small fetal size/age, large maternal body habitus, MOTION, and the fact that the mother was claustrophobic and uncomfortable and had to exit the scanner bore near the end of the scan session. Evaluation of fetal brain demonstrates lateral ventricles normal size and configuration. Measurement at atrial level 6.5 mm, bilaterally. Third and fourth ventricles uNREMARKABLE. Corpus callosum present although the full length is not evaluated. Gyral pattern within range for reported gestational age. CSF spaces normal. POSTERIOR FOSSA STRUCTURES NORMAL; transverse cerebellar diameter 21 mm. No brain parenchymal signal alteration or intracranial HEMORRHAGE. There is mild hypertelorism. There is a unilateral cleft lip-palate There is possible mild retrognathia on some of the images. Evaluation of individual vertebral segments particularly in the lower spine and sacrum is LIMITED. There appears to be mild S-shaped scoliosis of the spine. Thecal sac extends down to the sacral levels although evaluation of the sacrum itself is quite LIMITED. At least parts of the sacrum are present but further evaluation cannot be made. No spinal dysraphic sac is identified. The position of the conus cannot be determined. Please correlate with ultrasound. There appears to be bilateral talipes. Renal fusion anomaly. No hydronephrosis.
#
# IMPRESSION: MRI evaluation is partially LIMITED. 1. NO STRUCTURAL ABNORMALITY of the fetal brain visualized. 2. Unilateral right cleft lip and palate. Mild hypertelorism. Possible retrognathia on some of the sequences. 3. Scoliosis. Evaluation of the sacrum is LIMITED, but parts of the sacrum are present. No complete sacral agenesis, although evaluation of the morphology is LIMITED. 4. Bilateral talipes. Act 112^False
#
# Report id: 461104707187
# Why does Jenna think was this report given a 0:  limited due to motion
# What grade would you give it now:  1
# Who was correct, models or human?  models

# %%
df_report_eval = pd.DataFrame(l_report_reasons, columns=l_header)
fn_out = '/home/youngjm/arcus/shared/nlp_models_vs_graders/2024_models2_graders0.csv'
df_report_eval.to_csv(fn_out, sep='\t')

# %%
## Looking at the table
fn_out = '/home/youngjm/arcus/shared/nlp_models_vs_graders/2024_models2_graders0.csv'
df = pd.read_csv(fn_out, sep='\t')
df = df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#      proc_ord_id                                        orig_grader  \
# 0   466320194243        ['Zhiqiang Sha gave grade 0 on 2024-10-22']
# 1   467105809575     ['Jenna Schabdach gave grade 0 on 2024-08-27']
# 2   467155638267      ['Madison Dengel gave grade 0 on 2024-11-10']
# 3   473043201006     ['Jenna Schabdach gave grade 0 on 2024-08-21']
# 4   474384134481         ['Matt Buczek gave grade 0 on 2024-11-08']
# 5   474882822935      ['Madison Dengel gave grade 0 on 2024-11-10']
# 6   475307701443         ['Matt Buczek gave grade 0 on 2024-11-07']
# 7   475384629099         ['Matt Buczek gave grade 0 on 2024-11-08']
# 8   476326435341      ['Megan M. Himes gave grade 0 on 2024-10-29']
# 9   477096269940         ['Matt Buczek gave grade 0 on 2024-10-28']
# 10  478178208352  ['Jenna Schabdach gave grade 0 on 2024-09-18'\...
# 11  478178208352  ['Jenna Schabdach gave grade 0 on 2024-09-18'\...
# 12  478225407314   ['Dabriel Zimmerman gave grade 0 on 2024-10-08']
# 13  478233659854      ['Madison Dengel gave grade 0 on 2024-11-05']
# 14  452306181272       ['Naomi Shifman gave grade 0 on 2024-03-08']
# 15  452370087485       ['Naomi Shifman gave grade 0 on 2024-03-15']
# 16  453719846295        ['Alexa DeJean gave grade 0 on 2024-03-02']
# 17  454135824840  ['Shivaram Karandikar gave grade 0 on 2024-02-...
# 18  455026518468  ['Megan M. Himes gave grade 0 on 2024-02-29'\n...
# 19  455026518468  ['Megan M. Himes gave grade 0 on 2024-02-29'\n...
# 20  455325381373     ['Jenna Schabdach gave grade 0 on 2024-09-23']
# 21  455416666421        ['Eren Kafadar gave grade 0 on 2024-10-15']
# 22  455681412093      ['Megan M. Himes gave grade 0 on 2024-02-26']
# 23  455782849326      ['Megan M. Himes gave grade 0 on 2024-02-26']
# 24  455803165556      ['Julia Katowitz gave grade 0 on 2024-02-26']
# 25  456445634094  ['Shivaram Karandikar gave grade 0 on 2024-02-...
# 26  456885016640  ['Julia Katowitz gave grade 0 on 2024-02-25'\n...
# 27  456885016640  ['Julia Katowitz gave grade 0 on 2024-02-25'\n...
# 28  457813385549  ['Julia Katowitz gave grade 0 on 2024-02-27'\n...
# 29  457813385549  ['Julia Katowitz gave grade 0 on 2024-02-27'\n...
# 30  458503765584     ['Jenna Schabdach gave grade 0 on 2024-09-23']
# 31  458689835075     ['Jenna Schabdach gave grade 0 on 2024-09-23']
# 32  461104707187     ['Jenna Schabdach gave grade 0 on 2024-08-27']
#
#                                          reason_for_0  jenna_new_grade  \
# 0                                        macrocephaly                1
# 1   intraventricular hemorrhage associated with mi...                0
# 2                 concern of white matter volume loss                0
# 3   dysgenesis of corpus callosum, absent septum p...                0
# 4                                         volume loss                1
# 5   Constellation of findings concerning for sept-...                1
# 6   braces artifact obscured evaluation of the fro...                1
# 7                          suggestion of cerebellitis                1
# 8   no acute intracranial abnormality but thinned ...                1
# 9   braces artifact limiting frontal and anterior ...                1
# 10  herniated brain tissue compatible local enceph...                0
# 11  local encephalomalacia, herniation of a small ...                1
# 12   excessive patient motion, otherwise unremarkable                0
# 13  Findings suggestive of supratentorial volume loss                1
# 14                                             motion                1
# 15     findings are equivocal for pseudotumor cerebri                1
# 16  this examination is not of the typical quality...                2
# 17  this examination is not of the typical quality...                2
# 18                                     polymicrogyria                0
# 19                                     polymicrogyria                0
# 20                 Dandy-Walker malformation in fetus                0
# 21  objective macrocephaly with possible early ons...                1
# 22  focal cortical dysplagia and missing prior art...                1
# 23  14 mm area of FLAIR hyperintensity with no mas...                1
# 24  non specific hyperintense signal and hypoplasi...                2
# 25                                        volume loss                1
# 26              clinical indication of encephalopathy                1
# 27              clinical indication of encephalopathy                1
# 28    moderate infratentorial parenchymal volume loss                0
# 29    moderate infratentorial parenchymal volume loss                0
# 30  fetal scan, complete corpus callosum agenesis ...                0
# 31                 fetal scan, absent corpus callosum                0
# 32                              limited due to motion                1
#
#    correct_grader
# 0          models
# 1           human
# 2           human
# 3           human
# 4         unclear
# 5         unclear
# 6          models
# 7          models
# 8         unclear
# 9          models
# 10          human
# 11        unclear
# 12          human
# 13        unclear
# 14         models
# 15         models
# 16         models
# 17         models
# 18          human
# 19          human
# 20        unclear
# 21        unclear
# 22         models
# 23         models
# 24         models
# 25         models
# 26        unclear
# 27        unclear
# 28          human
# 29          human
# 30        unclear
# 31        unclear
# 32         models
